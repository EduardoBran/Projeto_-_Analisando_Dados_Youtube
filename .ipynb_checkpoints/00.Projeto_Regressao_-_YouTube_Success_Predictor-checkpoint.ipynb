# %% [markdown]
# # <span style="color: green; font-size: 40px; font-weight: bold;"> Projeto 16 (Regressão) </span>
#
# <br> <br>
#
# # Projeto YouTube Success Predictor
#
# <br>
#
# ### Contexto
#
# - Você é um analista de dados contratado por uma agência de marketing digital chamada Creative Content Network (CCN), especializada em otimizar a presença e o desempenho de canais do YouTube. A agência deseja utilizar os dados disponíveis para entender melhor os fatores que influenciam os ganhos mensais estimados dos canais de YouTube. Com essas informações, a agência pretende fornecer insights estratégicos para seus clientes, ajudando-os a aumentar seus ganhos e otimizar suas estratégias de conteúdo.
#
# <br>
#
# ## Objetivo Principal do Projeto
#
# - Desenvolver um modelo de machine learning para prever os ganhos mensais estimados de um canal do YouTube com base nas características do canal e nos dados socioeconômicos do país de origem.
#
# #### O que a empresa espera receber
#
# - A Creative Content Network (CCN) espera receber um conjunto de ferramentas e análises que possibilitem prever o crescimento dos inscritos em canais do YouTube e fornecer insights estratégicos para otimizar seus esforços de marketing e gestão.
#
# <br>
#
# ### Entregáveis do Projeto
#
# #### Modelo Preditivo
# > Um modelo de machine learning treinado para prever o número de novos inscritos em um canal do YouTube nos próximos 30 dias com base nas características do canal.
#
# #### Interface Interativa
# > Uma aplicação web interativa onde os usuários poderão inserir características específicas de um canal do YouTube e obter a previsão do número de novos inscritos para os próximos 30 dias.
# A interface permitirá a entrada de variáveis como categoria do canal, número de visualizações, frequência de uploads, país de origem, e outras características relevantes.
#
# #### Relatório de Análise e Insights
# > Insights acionáveis sobre as características que mais influenciam o crescimento de inscritos.
# Recomendações estratégicas baseadas nos resultados do modelo preditivo.
#
# #### Dashboard de Visualização
# > Um dashboard interativo que permite aos usuários explorar os dados e visualizar tendências, padrões e previsões.
# Gráficos e visualizações que mostram a distribuição de inscritos, visualizações de vídeos, categorias mais populares, e outras métricas relevantes.
#
# ### Perguntas de Negócios Adicionais
#
# - 1. Quais são os principais fatores que influenciam os ganhos mensais de um canal do YouTube?
# - 2. Como o tipo de canal (por exemplo, Educação, Entretenimento) afeta os ganhos mensais?
# - 3. Qual é a relação entre as características socioeconômicas do país de origem do canal e os ganhos mensais do canal no YouTube?
# - 4. Quais estratégias podem ser recomendadas para canais de YouTube em diferentes países e categorias para maximizar os ganhos?
# - 5. Como as tendências de ganhos dos canais variam ao longo do tempo e quais são as previsões futuras para canais específicos?
# - 6. Quais métricas internas do canal (número de uploads, visualizações recentes, etc.) são mais preditivas dos ganhos mensais?
# - 7. Como a frequência de upload de novos vídeos afeta os ganhos mensais do canal?
# - 8. Quais são as melhores práticas para otimização de conteúdo que geram maior receita mensal?
#
# <br>
#
# ### Conclusão
#
# Com essa abordagem, a Creative Content Network (CCN) terá uma ferramenta poderosa para prever o crescimento de inscritos em canais do YouTube e tomar decisões estratégicas baseadas em dados. Isso permitirá à agência otimizar seus lançamentos e estratégias de marketing, aumentando as chances de sucesso de seus criadores de conteúdo no mercado competitivo de hoje.
#
# <br>
#
# ### Sobre o Conjunto de Dados
#
# Para este projeto, utilizaremos o conjunto de dados "Global YouTube Statistics", que contém informações sobre os maiores canais do YouTube, incluindo o número de inscritos, visualizações de vídeos, frequência de uploads, país de origem, e outras métricas relevantes.
#
# <table border="2">
#   <tr>
#     <th style="text-align: center; font-size: 16px;">Nome da Coluna</th>
#     <th style="text-align: center; font-size: 16px;">Tipo de Dado</th>
#     <th style="text-align: center; font-size: 16px;">Descrição</th>
#   </tr>
#   <tr>
#     <td>channel_name</td>
#     <td>object</td>
#     <td>Nome do canal no YouTube.</td>
#   </tr>
#   <tr>
#     <td>total_upload</td>
#     <td>int</td>
#     <td>Número total de vídeos enviados pelo canal.</td>
#   </tr>
#   <tr>
#     <td>total_subscribers</td>
#     <td>float</td>
#     <td>Número total de inscritos no canal.</td>
#   </tr>
#   <tr>
#     <td>total_video_views</td>
#     <td>float</td>
#     <td>Número total de visualizações de vídeos no canal.</td>
#   </tr>
#   <tr>
#     <td>country</td>
#     <td>object</td>
#     <td>País de origem do canal.</td>
#   </tr>
#   <tr>
#     <td>channel_type</td>
#     <td>object</td>
#     <td>Tipo de canal (por exemplo, Educação, Entretenimento, Música).</td>
#   </tr>
#   <tr>
#     <td>user_created</td>
#     <td>object</td>
#     <td>Data de criação do usuário no YouTube.</td>
#   </tr>
#   <tr>
#     <td>rank_social_blade</td>
#     <td>float</td>
#     <td>Rank do canal no Social Blade.</td>
#   </tr>
#   <tr>
#     <td>rank_subscribers</td>
#     <td>float</td>
#     <td>Rank do canal baseado no número de inscritos.</td>
#   </tr>
#   <tr>
#     <td>rank_video_views</td>
#     <td>float</td>
#     <td>Rank do canal baseado no número de visualizações de vídeos.</td>
#   </tr>
#   <tr>
#     <td>rank_country</td>
#     <td>object</td>
#     <td>Rank do canal dentro de seu país.</td>
#   </tr>
#   <tr>
#     <td>rank_education</td>
#     <td>object</td>
#     <td>Rank do canal dentro da categoria de Educação (valores ausentes).</td>
#   </tr>
#   <tr>
#     <td>estimated_monthly_earnings</td>
#     <td>object</td>
#     <td>Estimativa de ganhos mensais do canal.</td>
#   </tr>
#   <tr>
#     <td>estimated_yearly_earnings</td>
#     <td>object</td>
#     <td>Estimativa de ganhos anuais do canal.</td>
#   </tr>
#   <tr>
#     <td>videos_views_last_30_days</td>
#     <td>float</td>
#     <td>Número de visualizações de vídeos nos últimos 30 dias.</td>
#   </tr>
#   <tr>
#     <td>subscribers_for_last_30_days</td>
#     <td>float</td>
#     <td>Número de inscritos ganhos nos últimos 30 dias.</td>
#   </tr>
#   <tr>
#     <td>rank_channel_type</td>
#     <td>object</td>
#     <td>Rank do canal dentro de sua categoria de tipo (valores ausentes).</td>
#   </tr>
#   <tr>
#     <td>Populacao_2022</td>
#     <td>float</td>
#     <td>População do país de origem do canal em 2022.</td>
#   </tr>
#   <tr>
#     <td>PIB_Nominal_2022</td>
#     <td>float</td>
#     <td>PIB nominal do país de origem do canal em 2022.</td>
#   </tr>
#   <tr>
#     <td>PIB_per_Capita_2022</td>
#     <td>float</td>
#     <td>PIB per capita do país de origem do canal em 2022.</td>
#   </tr>
#   <tr>
#     <td>Exp_de_Vida_2022</td>
#     <td>float</td>
#     <td>Expectativa de vida no país de origem do canal em 2022.</td>
#   </tr>
#   <tr>
#     <td>Taxa_de_Natalidade</td>
#     <td>float</td>
#     <td>Taxa de natalidade no país de origem do canal.</td>
#   </tr>
#   <tr>
#     <td>taxa_alfabetizacao_total_%</td>
#     <td>float</td>
#     <td>Taxa de alfabetização total no país de origem do canal.</td>
#   </tr>
#   <tr>
#     <td>taxa_alfabetizacao_masculina_%</td>
#     <td>float</td>
#     <td>Taxa de alfabetização masculina no país de origem do canal.</td>
#   </tr>
#   <tr>
#     <td>taxa_alfabetizacao_feminina_%</td>
#     <td>float</td>
#     <td>Taxa de alfabetização feminina no país de origem do canal.</td>
#   </tr>
#   <tr>
#     <td>diferenca_alfabetizacao_masculino_feminino</td>
#     <td>float</td>
#     <td>Diferença na taxa de alfabetização entre homens e mulheres no país de origem do canal.</td>
#   </tr>
#   <tr>
#     <td>Taxa_Desemprego_2022_%</td>
#     <td>float</td>
#     <td>Taxa de desemprego no país de origem do canal em 2022.</td>
#   </tr>
#   <tr>
#     <td>Taxa_de_Pobreza</td>
#     <td>float</td>
#     <td>Taxa de pobreza no país de origem do canal.</td>
#   </tr>
#   <tr>
#     <td>Indice_de_Watts</td>
#     <td>float</td>
#     <td>Índice de Watts (indicador de desenvolvimento econômico e social).</td>
#   </tr>
#   <tr>
#     <td>Human_Development_Groups</td>
#     <td>object</td>
#     <td>Grupos de Desenvolvimento Humano do país de origem do canal.</td>
#   </tr>
#   <tr>
#     <td>IDH_2021</td>
#     <td>float</td>
#     <td>Índice de Desenvolvimento Humano do país de origem do canal em 2021.</td>
#   </tr>
#   <tr>
#     <td>Indice_Corrupcao_Score</td>
#     <td>float</td>
#     <td>Índice de percepção de corrupção do país de origem do canal.</td>
#   </tr>
#   <tr>
#     <td>Nivel_Urbanizacao_2023_%_da_Pop</td>
#     <td>float</td>
#     <td>Nível de urbanização do país de origem do canal em 2023.</td>
#   </tr>
# </table>
#
# <br>
#
# > A variável alvo do nosso projeto é a coluna **estimated_monthly_earnings**, que representa a estimativa de ganhos mensais do canal do YouTube. O objetivo é prever os ganhos mensais com base nas características dos canais do YouTube e nos dados socioeconômicos do país de origem.

# %% [markdown]
# <br><br>
#
# ## Importando Pacotes

# %%
### Manipulação de Dados ###

# NumPy: Biblioteca para operações matemáticas e manipulação de arrays.
import numpy as np
# Pandas: Biblioteca para manipulação e análise de dados estruturados.
import pandas as pd

from sklearn.preprocessing import LabelEncoder
from scipy.stats import mstats

### Exibição de Gráficos ###

# Matplotlib: Biblioteca para criação de gráficos e visualizações.
import matplotlib.pyplot as plt
# Seaborn: Biblioteca para criação de gráficos estatísticos e visualizações.
import seaborn as sns


### Machine Learning ###

# Scikit-learn: Biblioteca para ML, incluindo ferramentas para pré-processamento, modelagem, e avaliação.
import sklearn
# Train Test Split: Função para dividir os dados em conjuntos de treino e teste.
from sklearn.model_selection import train_test_split
# StandardScaler: Ferramenta para padronização de recursos, ajustando a média e a variância.
from sklearn.preprocessing import StandardScaler
# LinearRegression, Ridge, Lasso: Algoritmos de regressão linear, incluindo regularização L2 (Ridge) e L1 (Lasso).
from sklearn.linear_model import LinearRegression, Ridge, Lasso

# Seleção de Hiperparâmetros
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import ElasticNet            # Algoritmo de Regressão
from sklearn.tree import DecisionTreeRegressor         # Algoritmo de Regressão

from sklearn.ensemble import RandomForestRegressor     # Algoritmo de Regressão
from sklearn.svm import SVR                            # Algoritmo de Regressão

from sklearn.neighbors import KNeighborsRegressor      # Algoritmo de Regressão
from sklearn.ensemble import GradientBoostingRegressor # Algoritmo de Regressão
import xgboost as xgb                                  # Algoritmo de Regressão
from xgboost import XGBRegressor                       # Algoritmo de Regressão
from sklearn.cluster import KMeans


from datetime import datetime

# Configura o pandas para exibir todas as colunas
pd.set_option('display.max_columns', None)


### Avaliação de Modelos ### 

# Métricas para avaliar o desempenho
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, explained_variance_score


### Configurações Adicionais ###

# Configuração de estilo para visualizações Seaborn.
sns.set_style('whitegrid')
# Inline: Para exibir gráficos diretamente no Jupyter Notebook.
# %matplotlib inline
# Warnings: Biblioteca para gerenciar mensagens de aviso, aqui usada para ignorar avisos futuros.
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
# Ignorando avisos de depreciação
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# <br><br>
#
# ## Carregando Conjunto de Dados

# %%
# Carrega o dataset com a codificação correta
dados = pd.read_csv('dados/datasets_modificados/dados_completos_atualizado.csv', encoding='ISO-8859-1')

# Visualizando
display(dados.head())

print(dados.shape)
print(dados.columns)
# Out:
#                         channel_name  total_upload  total_subscribers  \
# 0                  shut up (Skay :v)            72            70800.0
# 1  Bindaas Tv - Funny Comedy Stories           384          4100000.0
# 2                          boburnham            35          3680000.0
# 3                    Azmir Recording          3703          1930000.0
# 4                      LiamPayneVEVO            49          1480000.0
#
#    total_video_views      country   channel_type    user_created  \
# 0       1.224873e+07  Afghanistan         People  May 27th, 2016
# 1       1.277637e+09  Afghanistan  Entertainment  Sep 10th, 2019
# 2       8.913827e+08  Afghanistan         Comedy  Jul 11th, 2006
# 3       3.679132e+08  Afghanistan  Entertainment   Jan 3rd, 2017
# 4       7.852759e+08  Afghanistan          Music  Aug 15th, 2016
#
#    rank_social_blade  rank_subscribers  rank_video_views rank_country  \
# 0           914134.0            2789.0          881538.0           83
# 1           109567.0             955.0           12079.0            1
# 2            67156.0            1000.0           18740.0            2
# 3           254881.0            1179.0           48725.0            3
# 4           349028.0            1226.0           21567.0            5
#
#   rank_education estimated_monthly_earnings estimated_yearly_earnings  \
# 0           2108                0.02 - 0.32                    81 - 4
# 1            750               1.2K - 19.7K             4.937M - 237K
# 2            349               2.2K - 35.6K             8.895M - 427K
# 3            968                 371 - 5.9K            1.486M - 71.3K
# 4            846                 244 - 3.9K          975.249K - 46.8K
#
#    videos_views_last_30_days  subscribers_for_last_30_days rank_channel_type  \
# 0                       81.0                        -100.0               NaN
# 1                  4937000.0                       10000.0               NaN
# 2                  8895000.0                       10000.0               NaN
# 3                  1486000.0                       20000.0               NaN
# 4                   975249.0                           0.0               NaN
#
#    Populacao_2022  PIB_Nominal_2022  PIB_per_Capita_2022  Exp_de_Vida_2022  \
# 0      41128771.0      1.427000e+10           352.603733            62.879
# 1      41128771.0      1.427000e+10           352.603733            62.879
# 2      41128771.0      1.427000e+10           352.603733            62.879
# 3      41128771.0      1.427000e+10           352.603733            62.879
# 4      41128771.0      1.427000e+10           352.603733            62.879
#
#    Taxa_de_Natalidade  taxa_alfabetizacao_total_%  \
# 0               32.49                        38.2
# 1               32.49                        38.2
# 2               32.49                        38.2
# 3               32.49                        38.2
# 4               32.49                        38.2
#
#    taxa_alfabetizacao_masculina_%  taxa_alfabetizacao_feminina_%  \
# 0                            52.0                           24.2
# 1                            52.0                           24.2
# 2                            52.0                           24.2
# 3                            52.0                           24.2
# 4                            52.0                           24.2
#
#    diferenca_alfabetizacao_masculino_feminino  Taxa_Desemprego_2022_%  \
# 0                                        27.8                    14.1
# 1                                        27.8                    14.1
# 2                                        27.8                    14.1
# 3                                        27.8                    14.1
# 4                                        27.8                    14.1
#
#    Taxa_de_Pobreza  Indice_de_Watts Human_Development_Groups  IDH_2021  \
# 0            0.494           0.2876                      Low     0.478
# 1            0.494           0.2876                      Low     0.478
# 2            0.494           0.2876                      Low     0.478
# 3            0.494           0.2876                      Low     0.478
# 4            0.494           0.2876                      Low     0.478
#
#    Indice_Corrupcao_Score  Nivel_Urbanizacao_2023_%_da_Pop
# 0                    20.0                           26.616
# 1                    20.0                           26.616
# 2                    20.0                           26.616
# 3                    20.0                           26.616
# 4                    20.0                           26.616
# (1349, 33)
# Index(['channel_name', 'total_upload', 'total_subscribers',
#        'total_video_views', 'country', 'channel_type', 'user_created',
#        'rank_social_blade', 'rank_subscribers', 'rank_video_views',
#        'rank_country', 'rank_education', 'estimated_monthly_earnings',
#        'estimated_yearly_earnings', 'videos_views_last_30_days',
#        'subscribers_for_last_30_days', 'rank_channel_type', 'Populacao_2022',
#        'PIB_Nominal_2022', 'PIB_per_Capita_2022', 'Exp_de_Vida_2022',
#        'Taxa_de_Natalidade', 'taxa_alfabetizacao_total_%',
#        'taxa_alfabetizacao_masculina_%', 'taxa_alfabetizacao_feminina_%',
#        'diferenca_alfabetizacao_masculino_feminino', 'Taxa_Desemprego_2022_%',
#        'Taxa_de_Pobreza', 'Indice_de_Watts', 'Human_Development_Groups',
#        'IDH_2021', 'Indice_Corrupcao_Score',
#        'Nivel_Urbanizacao_2023_%_da_Pop'],
#       dtype='object')

# %% [markdown]
# <br><br><br>
#
# # <span style="color: green; font-size: 34px; font-weight: bold;"> Análise Exploratória de Dados </span>
#
# <br>
#
# ### Análise Inicial

# %%
# Informações do DataFrame
print('\n\n INFO \n\n')
dados.info()
print('\n\n ------------------------------------------------------------------------------------------ \n\n')

# Verifica se há valores ausentes e duplicados
valores_ausentes = dados.isna().sum().sum() > 0
valores_duplicados = dados.duplicated().sum() > 0

# Nomes das variáveis com valores ausentes
variaveis_ausentes = dados.columns[dados.isna().any()].tolist()

# Número de linhas duplicadas
num_linhas_duplicadas = dados.duplicated().sum()

# Porcentagem de linhas duplicadas
porcentagem_linhas_duplicadas = (num_linhas_duplicadas / len(dados)) * 100

# Exibe o resultado
print("\n\nExistem valores ausentes:", valores_ausentes)
if valores_ausentes:
    print("\nVariáveis com valores ausentes:", variaveis_ausentes)
else:
    print("\nNenhuma variável possui valores ausentes.")

print("\n\nExistem valores duplicados:", valores_duplicados)
if valores_duplicados:
    print("\nNúmero de Linhas Duplicadas:", num_linhas_duplicadas)
    print("\nPorcentagem de Linhas Duplicadas: {:.2f}%".format(porcentagem_linhas_duplicadas))
else:
    print("\nNenhuma variável possui valores duplicados.")
# Out:
#  INFO
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1349 entries, 0 to 1348
# Data columns (total 33 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   channel_name                                1349 non-null   object
#  1   total_upload                                1349 non-null   int64
#  2   total_subscribers                           1349 non-null   float64
#  3   total_video_views                           1349 non-null   float64
#  4   country                                     1349 non-null   object
#  5   channel_type                                1349 non-null   object
#  6   user_created                                1349 non-null   object
#  7   rank_social_blade                           1349 non-null   float64
#  8   rank_subscribers                            1349 non-null   float64
#  9   rank_video_views                            1349 non-null   float64
#  10  rank_country                                1349 non-null   object
#  11  rank_education                              511 non-null    object
#  12  estimated_monthly_earnings                  1349 non-null   object
#  13  estimated_yearly_earnings                   1349 non-null   object
#  14  videos_views_last_30_days                   1349 non-null   float64
#  15  subscribers_for_last_30_days                1349 non-null   float64
#  16  rank_channel_type                           456 non-null    object
#  17  Populacao_2022                              1349 non-null   float64
#  18  PIB_Nominal_2022                            1349 non-null   float64
#  19  PIB_per_Capita_2022                         1349 non-null   float64
#  20  Exp_de_Vida_2022                            1349 non-null   float64
#  21  Taxa_de_Natalidade                          1349 non-null   float64
#  22  taxa_alfabetizacao_total_%                  1349 non-null   float64
#  23  taxa_alfabetizacao_masculina_%              1349 non-null   float64
#  24  taxa_alfabetizacao_feminina_%               1349 non-null   float64
#  25  diferenca_alfabetizacao_masculino_feminino  1349 non-null   float64
#  26  Taxa_Desemprego_2022_%                      1349 non-null   float64
#  27  Taxa_de_Pobreza                             1349 non-null   float64
#  28  Indice_de_Watts                             1349 non-null   float64
#  29  Human_Development_Groups                    1349 non-null   object
#  30  IDH_2021                                    1349 non-null   float64
#  31  Indice_Corrupcao_Score                      1349 non-null   float64
#  32  Nivel_Urbanizacao_2023_%_da_Pop             1349 non-null   float64
# dtypes: float64(22), int64(1), object(10)
# memory usage: 347.9+ KB
#
#
#  ------------------------------------------------------------------------------------------
#
#
#
#
# Existem valores ausentes: True
#
# Variáveis com valores ausentes: ['rank_education', 'rank_channel_type']
#
#
# Existem valores duplicados: False
#
# Nenhuma variável possui valores duplicados.

# %% [markdown]
# ### Excluindo Variáveis com Valores Nulos

# %%
# Excluir variáveis com valores ausentes
dados.drop(columns=['rank_education', 'rank_channel_type'], inplace=True)

# %% [markdown]
# <br><br>
#
# # Analisando os Dados
#
# <br>
#
# #### Visualizando Variáveis Categóricas e Numéricas

# %%
# Exibindo Variáveis Categóricas (filtrando)
dados.dtypes[dados.dtypes == 'object']
# Out:
# channel_name                  object
# country                       object
# channel_type                  object
# user_created                  object
# rank_country                  object
# estimated_monthly_earnings    object
# estimated_yearly_earnings     object
# Human_Development_Groups      object
# dtype: object

# %%
# Exibindo Variáveis Numéricas (filtrando)
dados.dtypes[dados.dtypes != 'object']
# Out:
# total_upload                                    int64
# total_subscribers                             float64
# total_video_views                             float64
# rank_social_blade                             float64
# rank_subscribers                              float64
# rank_video_views                              float64
# videos_views_last_30_days                     float64
# subscribers_for_last_30_days                  float64
# Populacao_2022                                float64
# PIB_Nominal_2022                              float64
# PIB_per_Capita_2022                           float64
# Exp_de_Vida_2022                              float64
# Taxa_de_Natalidade                            float64
# taxa_alfabetizacao_total_%                    float64
# taxa_alfabetizacao_masculina_%                float64
# taxa_alfabetizacao_feminina_%                 float64
# diferenca_alfabetizacao_masculino_feminino    float64
# Taxa_Desemprego_2022_%                        float64
# Taxa_de_Pobreza                               float64
# Indice_de_Watts                               float64
# IDH_2021                                      float64
# Indice_Corrupcao_Score                        float64
# Nivel_Urbanizacao_2023_%_da_Pop               float64
# dtype: object

# %% [markdown]
# <br>
#
# # Separando Conjunto de Dados Para Machine Learning e Dashboard

# %%
dados_ml = dados.copy()
dados_da = dados.copy()

# %% [markdown]
# <br>
#
# ## Trabalhando no Conjunto de Dados para ML
#
# <br>
#
# #### Removendo coluna 'channel_name'

# %%
# Excluir variáveis com valores ausentes
dados_ml.drop(columns=['channel_name'], inplace=True)

# %% [markdown]
# <br><br>
#
# ## Analisando Variáveis Categóricas
#
# #### Resumo Estatístico

# %%
# Describe (informando que é para somente variáveis categóricas)
print('\nDescribe\n')
display(dados_ml.describe(include = ['object']))
print('\n------------------------------------------------------------------------\n\n')

# Verificando Tipo das Variáveis (adicionar mais variáveis se necessário)
print('\nTipo das Variáveis\n')
print(dados_ml['country'].unique())
print(dados_ml['channel_type'].unique())
print(dados_ml['user_created'].unique())
print(dados_ml['rank_country'].unique())
print(dados_ml['estimated_monthly_earnings'].unique())
print(dados_ml['estimated_yearly_earnings'].unique())
print(dados_ml['Human_Development_Groups'].unique())
# Out:
# Describe
#               country   channel_type    user_created rank_country  \
# count            1349           1349            1349         1349
# unique             90             17            1194          760
# top     United States  Entertainment  Mar 13th, 2022            1
# freq              252            276               4           38
#
#        estimated_monthly_earnings estimated_yearly_earnings  \
# count                        1349                      1349
# unique                       1230                      1288
# top                         0 - 0                   $0 - $0
# freq                           21                        14
#
#        Human_Development_Groups
# count                      1349
# unique                        4
# top                   Very High
# freq                        723
# ------------------------------------------------------------------------
#
#
#
# Tipo das Variáveis
#
# ['Afghanistan' 'Albania' 'Algeria' 'Andorra' 'Angola' 'Argentina'
#  'Armenia' 'Australia' 'Austria' 'Azerbaijan' 'Bangladesh' 'Barbados'
#  'Belarus' 'Belgium' 'Bolivia' 'Bosnia and Herzegovina' 'Brazil'
#  'Bulgaria' 'Cameroon' 'Canada' 'Chile' 'China' 'Colombia' 'Congo'
#  'Cooks Islands' 'Costa Rica' 'Croatia' 'Cyprus' 'Czech Republic'
#  'Denmark' 'Dominica' 'Ecuador' 'Egypt' 'El Salvador' 'Estonia' 'Finland'
#  'France' 'Germany' 'Ghana' 'Greece' 'Hong Kong' 'Hungary' 'Iceland'
#  'India' 'Indonesia' 'Iraq' 'Ireland' 'Italy' 'Jamaica' 'Japan'
#  'Kazakhstan' 'Korean North' 'Latvia' 'Liechtenstein' 'Lithuania'
#  'Malaysia' 'Mexico' 'Moldova' 'Morocco' 'Netherlands' 'New Zealand'
#  'Norway' 'Pakistan' 'Panama' 'Paraguay' 'Peru' 'Philippines' 'Portugal'
#  'Puerto Rico' 'Romania' 'Russia' 'San Marino' 'Saudi Arabia' 'Serbia'
#  'Singapore' 'South Africa' 'South Korea' 'Spain' 'Sweden' 'Switzerland'
#  'Thailand' 'Tunisia' 'Turkey' 'Ukraine' 'United Arab Emirates'
#  'United Kingdom' 'United States' 'Unknown' 'Uruguay' 'Vietnam']
# ['People' 'Entertainment' 'Comedy' 'Music' 'Sports' 'Games' 'Education'
#  'News' 'Unknown' 'Travel' 'Howto' 'Autos' 'Shows' 'Tech' 'Film'
#  'Nonprofit' 'Animals']
# ['May 27th, 2016' 'Sep 10th, 2019' 'Jul 11th, 2006' ... 'Nov 12th, 2020'
#  'May 16th, 2015' 'Mar 16th, 2020']
# ['83' '1' '2' '3' '5' '11' '124' '116' '97' '4' '92' '100' '404' '26'
#  '114' '219' '41' '35' '17' '96' '221' '20' '79' '234' '176.0' '391' '677'
#  '12' '55' '770' '210' '8' '6' '34' '32' '15' '256' '19' '1.0' '2.0' '139'
#  '333' '701' '4052.0' '63' '212' '66' '782' '144' '49' '126' '133' '638'
#  '274' '71' '10' '21' '330' '82' '39' '9' '47' '129' '29.0' '42.0' '89'
#  '24' '81' '540' '521' '152' '431' '2110' '2734' '563.0' '37' '483' '485'
#  '668' '552' '44' '570.0' '23' '31' '1319' '46' '182' '264' '967' '1877.0'
#  '640.0' '5507' '1491.0' '1462.0' '33.0' '1500.0' '285' '408.0' '2526.0'
#  '51' '84' '59' '43' '33' '25' '6162.0' '16' '4860' '825' '6125.0' '60.0'
#  '43.0' '2722' '34.0' '8.0' '851' '2770' '263' '455' '659' '178.0'
#  '3821.0' '294' '1550.0' '292' '598' '3309.0' '2265' '641' '651' '1050.0'
#  '29' '54' '40' '62' '8272' '57' '56' '1696' '262' '521.0' '673' '295'
#  '657' '65' '55.0' '576.0' '551.0' '1303' '656' '394' '326' '25.0' '789'
#  '6216' '314' '27' '3487.0' '1709.0' '422' '972.0' '744' '1173' '18' '53'
#  '624' '666' '153' '7' '653.0' '706.0' '1194' '463' '73' '61' '506' '627'
#  '577' '1880' '402' '1253' '1364' '523.0' '255' '177' '90' '1557' '2751.0'
#  '2514.0' '4788.0' '715' '457.0' '118.0' '6039.0' '1599.0' '536.0'
#  '5257.0' '1134.0' '3003.0' '1332.0' '301.0' '1273.0' '4166.0' '1276.0'
#  '1981.0' '2220.0' '1894.0' '3822.0' '2060.0' '2349.0' '1019' '1123.0'
#  '131' '618' '22.0' '516.0' '737.0' '4795.0' '1070.0' '6006' '2217.0'
#  '275' '343.0' '495' '564.0' '1225' '1761.0' '1439' '1029' '112' '6145'
#  '377.0' '352.0' '678.0' '353' '1890.0' '2162' '58' '69' '140' '385'
#  '1681' '22' '366' '115' '8566' '278' '250' '132' '204' '492' '45' '7.0'
#  '11.0' '3112' '1592' '13' '36' '194' '85' '538' '389' '721' '740' '50'
#  '612' '145' '543' '46.0' '20.0' '384' '290' '14' '1845' '137' '1004.0'
#  '448' '151' '845' '2012' '560' '213' '643' '1004' '1193' '1007' '136'
#  '86' '1027' '849' '899' '51.0' '300' '606' '984' '806' '1603' '989' '155'
#  '181' '683' '828' '180' '928' '544' '748' '961' '681' '193' '235' '246'
#  '228.0' '1263' '67' '186' '164' '568' '95' '149' '299' '361' '98' '74'
#  '72' '138.0' '603' '188.0' '270' '531' '78' '751.0' '933.0' '144.0'
#  '89.0' '397' '108' '71.0' '530.0' '1026.0' '714.0' '104' '388' '319'
#  '623' '631' '933' '328' '644.0' '68' '227' '419' '321' '183.0' '592'
#  '265' '219.0' '268.0' '558.0' '604' '663' '146.0' '305' '661.0' '184.0'
#  '168.0' '184' '198.0' '290.0' '185' '229' '304' '248' '690.0' '376.0'
#  '270.0' '145.0' '172.0' '635' '814' '176' '832.0' '432' '1000.0' '870.0'
#  '167.0' '136.0' '70.0' '656.0' '465' '172' '137.0' '154' '640' '42'
#  '166.0' '113' '711.0' '121' '2168' '186.0' '150.0' '279' '731.0' '354.0'
#  '86.0' '13.0' '1593' '604.0' '171' '414.0' '605.0' '780.0' '173' '1868'
#  '787.0' '36.0' '75' '572' '94' '201' '28' '174' '817' '254' '196' '60'
#  '411.0' '230' '187' '332' '165' '30.0' '487.0' '871' '425' '70' '799'
#  '979' '708' '325' '102' '120' '2544' '392' '820' '1161' '621.0' '434'
#  '354' '106' '411' '277' '30' '898' '341' '52' '771' '757.0' '310.0' '208'
#  '179' '562' '272' '224' '833' '835' '301' '48' '211' '50.0' '466' '805'
#  '47.0' '1428' '271' '1336.0' '79.0' '1296' '203' '798' '9.0' '1134' '687'
#  '600' '751' '546' '222.0' '1263.0' '462' '231' '1295' '259' '1620' '322'
#  '205' '412' '584' '511' '924' '197' '249' '189' '4.0' '38' '16.0' '1128'
#  '399' '77' '829' '117' '1219.0' '169' '881' '1374' '822' '426' '2911'
#  '768' '229.0' '1825' '4368.0' '1030.0' '2600' '3796.0' '387.0' '200.0'
#  '320.0' '449' '127' '17.0' '1716' '148' '119' '601' '209.0' '401.0' '110'
#  '427' '1035.0' '80' '288' '977' '936' '925' '1176' '297' '869' '375'
#  '241' '541' '163' '2881' '688' '341.0' '18.0' '954' '579.0' '1492.0'
#  '227.0' '575' '822.0' '1555.0' '1203.0' '10.0' '1024' '447' '6.0' '52.0'
#  '1284' '444.0' '3045' '1957.0' '451' '800' '170' '247' '3105' '190'
#  '1265' '475.0' '680' '879' '261' '1127' '642' '1541.0' '632' '88' '1036'
#  '37.0' '1338' '742' '215' '76' '1154' '495.0' '101' '856' '3773.0' '147'
#  '386' '765' '1969' '3046' '1921' '2204' '377' '173.0' '4534.0' '945'
#  '2449' '2141' '735' '2615' '1975' '2401' '202' '1888' '1952' '2413'
#  '2201' '1909' '639' '669.0' '4659' '3036' '2460' '1633' '1500' '9750'
#  '962.0' '1843.0' '1288.0' '1388' '1279.0' '103.0' '106.0' '699' '589'
#  '2551' '480' '1875.0' '2413.0' '178' '49.0' '192.0' '135' '2063.0' '161'
#  '233' '770.0' '1755' '138' '171.0' '1781.0' '555.0' '2500' '--' '1115.0'
#  '1446.0' '196.0' '752' '122' '758' '548' '223.0' '1285' '943' '990.0'
#  '9791.0' '754' '517' '139.0' '1028.0' '1441' '218' '200' '7953' '857'
#  '894' '2438' '1907' '351' '2637' '1487.0' '1165' '1262.0' '725' '1917'
#  '870' '475' '2258' '1417' '1827' '472' '266' '593' '591' '156' '217'
#  '53.0' '2396' '1990' '166' '949' '614' '1295.0' '91.0' '199' '507'
#  '455.0' '220.0' '1023.0' '1423.0' '892' '1521' '2290' '474' '1876'
#  '674.0' '72.0' '576' '981' '24.0' '1096.0' '195.0' '1942' '854' '302'
#  '1001' '946' '2325' '1614' '115.0' '630' '794.0' '847' '1013' '159'
#  '676.0' '245' '807' '509' '931' '1924.0' '477' '967.0' '207.0' '991'
#  '1255' '162' '5553' '156.0' '9463' '610' '6101' '45.0' '93' '241.0'
#  '98.0']
# ['0.02 - 0.32' '1.2K - 19.7K' '2.2K - 35.6K' ... '37.2K - 594.5K'
#  '$166 - $2.7K' '138.8K - 2.2M']
# ['81 - 4' '4.937M - 237K' '8.895M - 427K' ... '445.8K - 7.1M' '$2K - $32K'
#  '1.7M - 26.7M']
# ['Low' 'High' 'Very High' 'Medium']

# %% [markdown]
# <br>
#
# #### Visualizando através de Gráficos

# %%
# Exibir os gráficos de contagem para todas as variáveis categóricas (adicionar variáveis categóricas necessárias)
categorical_vars = ['channel_type', 'Human_Development_Groups']

for var in categorical_vars:
    plt.figure(figsize=(10, 6))
    sns.countplot(data=dados, x=var, label='Count')
    plt.title(f'Contagem de {var}')
    plt.xlabel(var.replace('_', ' ').capitalize())
    plt.ylabel('Contagem')
    plt.xticks(rotation=45)
    plt.show()

# Value counts para todas as variáveis categóricas
for var in categorical_vars:
    var_counts = dados[var].value_counts()
    print(f"\nContagem de {var.replace('_', ' ').capitalize()}:")
    for category, count in var_counts.items():
        print(f'{category}: {count}')
# Out:
# Contagem de Channel type:
# Entertainment: 276
# Music: 205
# People: 172
# Education: 134
# Sports: 102
# Games: 97
# Comedy: 94
# Film: 78
# Tech: 31
# Autos: 29
# Howto: 27
# News: 25
# Unknown: 22
# Animals: 21
# Travel: 18
# Shows: 11
# Nonprofit: 7
#
# Contagem de Human development groups:
# Very High: 723
# High: 337
# Medium: 272
# Low: 17

# %% [markdown]
# ### Resumo da Análise
#
# - **Diversidade Geográfica**: O conjunto de dados abrange canais de 90 países diferentes, com os Estados Unidos sendo o mais representado.
# - **Variedade de Tipos de Canais**: Existem 17 tipos diferentes de canais, com Entertainment sendo o mais comum.
# - **Datas de Criação Variadas**: Os canais foram criados em várias datas ao longo dos anos.
# - **Grupos de Desenvolvimento Humano**: A maioria dos canais está em países com um Very High índice de desenvolvimento humano.
#
# <br>
#
# #### Tratar as seguintes variáveis:
#
# - user_created
# - estimated_monthly_earnings
# - estimated_yearly_earnings
#
# <br>
#
# ### Tratando Variáveis Categóricas
#
# <br>
#
# #### user_created
#
# - criar 4 novas colunas que representarão user_created na forma numérica

# %%
# Função para limpar a string de data
def clean_date_string(date_str):
    date_str = date_str.replace('th', '').replace('st', '').replace('nd', '').replace('rd', '')
    return date_str

# Função para extrair dia, mês e ano de uma string de data no formato 'MMM DD, YYYY'
def extract_date_components(date_str):
    date_str = clean_date_string(date_str)
    date_obj = pd.to_datetime(date_str, format='%b %d, %Y', errors='coerce')
    if pd.isnull(date_obj):
        return pd.NA, pd.NA, pd.NA
    return date_obj.day, date_obj.month, date_obj.year

# Aplicar a função para criar novas colunas
dados_ml['day_created'], dados_ml['month_created'], dados_ml['year_created'] = zip(*dados_ml['user_created'].apply(extract_date_components))


# Função para calcular a idade do canal
def calculate_channel_age(date_str):
    date_str = clean_date_string(date_str)
    date_obj = pd.to_datetime(date_str, format='%b %d, %Y', errors='coerce')
    if pd.isnull(date_obj):
        return pd.NA
    today = datetime.today()
    return (today.year - date_obj.year) - ((today.month, today.day) < (date_obj.month, date_obj.day))

# Aplicar a função para criar uma nova coluna de idade do canal
dados_ml['channel_age'] = dados_ml['user_created'].apply(calculate_channel_age)

# Remover a coluna user_created
dados_ml.drop(columns=['user_created'], inplace=True)


# Verificar se ainda existem valores nulos nas novas colunas
print('\nVerificando valores nulos nas novas colunas:')
print(dados_ml[['day_created', 'month_created', 'year_created', 'channel_age']].isnull().sum())

# Exibir as primeiras linhas para verificação
display(dados_ml.head())
# Out:
# Verificando valores nulos nas novas colunas:
# day_created      0
# month_created    0
# year_created     0
# channel_age      0
# dtype: int64
#    total_upload  total_subscribers  total_video_views      country  \
# 0            72            70800.0       1.224873e+07  Afghanistan
# 1           384          4100000.0       1.277637e+09  Afghanistan
# 2            35          3680000.0       8.913827e+08  Afghanistan
# 3          3703          1930000.0       3.679132e+08  Afghanistan
# 4            49          1480000.0       7.852759e+08  Afghanistan
#
#     channel_type  rank_social_blade  rank_subscribers  rank_video_views  \
# 0         People           914134.0            2789.0          881538.0
# 1  Entertainment           109567.0             955.0           12079.0
# 2         Comedy            67156.0            1000.0           18740.0
# 3  Entertainment           254881.0            1179.0           48725.0
# 4          Music           349028.0            1226.0           21567.0
#
#   rank_country estimated_monthly_earnings estimated_yearly_earnings  \
# 0           83                0.02 - 0.32                    81 - 4
# 1            1               1.2K - 19.7K             4.937M - 237K
# 2            2               2.2K - 35.6K             8.895M - 427K
# 3            3                 371 - 5.9K            1.486M - 71.3K
# 4            5                 244 - 3.9K          975.249K - 46.8K
#
#    videos_views_last_30_days  subscribers_for_last_30_days  Populacao_2022  \
# 0                       81.0                        -100.0      41128771.0
# 1                  4937000.0                       10000.0      41128771.0
# 2                  8895000.0                       10000.0      41128771.0
# 3                  1486000.0                       20000.0      41128771.0
# 4                   975249.0                           0.0      41128771.0
#
#    PIB_Nominal_2022  PIB_per_Capita_2022  Exp_de_Vida_2022  \
# 0      1.427000e+10           352.603733            62.879
# 1      1.427000e+10           352.603733            62.879
# 2      1.427000e+10           352.603733            62.879
# 3      1.427000e+10           352.603733            62.879
# 4      1.427000e+10           352.603733            62.879
#
#    Taxa_de_Natalidade  taxa_alfabetizacao_total_%  \
# 0               32.49                        38.2
# 1               32.49                        38.2
# 2               32.49                        38.2
# 3               32.49                        38.2
# 4               32.49                        38.2
#
#    taxa_alfabetizacao_masculina_%  taxa_alfabetizacao_feminina_%  \
# 0                            52.0                           24.2
# 1                            52.0                           24.2
# 2                            52.0                           24.2
# 3                            52.0                           24.2
# 4                            52.0                           24.2
#
#    diferenca_alfabetizacao_masculino_feminino  Taxa_Desemprego_2022_%  \
# 0                                        27.8                    14.1
# 1                                        27.8                    14.1
# 2                                        27.8                    14.1
# 3                                        27.8                    14.1
# 4                                        27.8                    14.1
#
#    Taxa_de_Pobreza  Indice_de_Watts Human_Development_Groups  IDH_2021  \
# 0            0.494           0.2876                      Low     0.478
# 1            0.494           0.2876                      Low     0.478
# 2            0.494           0.2876                      Low     0.478
# 3            0.494           0.2876                      Low     0.478
# 4            0.494           0.2876                      Low     0.478
#
#    Indice_Corrupcao_Score  Nivel_Urbanizacao_2023_%_da_Pop  day_created  \
# 0                    20.0                           26.616           27
# 1                    20.0                           26.616           10
# 2                    20.0                           26.616           11
# 3                    20.0                           26.616            3
# 4                    20.0                           26.616           15
#
#    month_created  year_created  channel_age
# 0              5          2016            8
# 1              9          2019            4
# 2              7          2006           17
# 3              1          2017            7
# 4              8          2016            7

# %% [markdown]
# <br>
#
# #### estimated_monthly_earnings
#
# - criar uma nova variável **Minimum_Estimated_Monthly_Earnings**.

# %%
# Função para extrair a estimativa mínima dos ganhos mensais
def extract_min_estimated_earnings(earnings_str):
    # Remover caracteres não numéricos e espaços e ajustar K, M, e B
    earnings_str = earnings_str.replace('$', '').replace(',', '').replace(' - ', '-')
    
    # Pegar os dois valores
    earnings_range = earnings_str.split('-')
    
    def convert_to_float(value):
        if value == '':
            return 0.0
        if 'K' in value:
            return float(value.replace('K', '')) * 1000
        elif 'M' in value:
            return float(value.replace('M', '')) * 1000000
        elif 'B' in value:
            return float(value.replace('B', '')) * 1000000000
        else:
            return float(value)
    
    # Converter o valor mínimo para float
    min_earnings = convert_to_float(earnings_range[0].strip())
    
    return min_earnings

# Aplicar a função para criar a nova coluna
dados_ml['Minimum_Estimated_Monthly_Earnings'] = dados_ml['estimated_monthly_earnings'].apply(extract_min_estimated_earnings)


# Verificar as primeiras linhas para confirmação
display(dados_ml[['estimated_monthly_earnings', 'Minimum_Estimated_Monthly_Earnings']].head())


# Remover a coluna user_created
dados_ml.drop(columns=['estimated_monthly_earnings'], inplace=True)
# Out:
#   estimated_monthly_earnings  Minimum_Estimated_Monthly_Earnings
# 0                0.02 - 0.32                                0.02
# 1               1.2K - 19.7K                             1200.00
# 2               2.2K - 35.6K                             2200.00
# 3                 371 - 5.9K                              371.00
# 4                 244 - 3.9K                              244.00

# %% [markdown]
# <br>
#
# #### estimated_yearly_earnings
#
# - Será removida, seus dados estão muito inconsistentes.

# %%
# Remover a coluna estimated_yearly_earnings
dados_ml.drop(columns=['estimated_yearly_earnings'], inplace=True)

# %% [markdown]
# <br>
#
# ### Reorganizado ordem das Colunas

# %%
# Reorganizar as colunas com a nova coluna na posição correta
colunas_reorganizadas = ['total_upload', 'total_subscribers', 'total_video_views', 'country',
                         'channel_type', 'day_created', 'month_created', 'year_created', 'channel_age',
                         'rank_social_blade', 'rank_subscribers', 'rank_video_views', 'rank_country',
                         'Minimum_Estimated_Monthly_Earnings', 'videos_views_last_30_days',
                         'subscribers_for_last_30_days', 'Populacao_2022', 'PIB_Nominal_2022',
                         'PIB_per_Capita_2022', 'Exp_de_Vida_2022', 'Taxa_de_Natalidade',
                         'taxa_alfabetizacao_total_%', 'taxa_alfabetizacao_masculina_%',
                         'taxa_alfabetizacao_feminina_%',
                         'diferenca_alfabetizacao_masculino_feminino', 'Taxa_Desemprego_2022_%',
                         'Taxa_de_Pobreza', 'Indice_de_Watts', 'Human_Development_Groups',
                         'IDH_2021', 'Indice_Corrupcao_Score',
                         'Nivel_Urbanizacao_2023_%_da_Pop']

dados_ml = dados_ml[colunas_reorganizadas]

# Exibir as primeiras linhas para verificação
display(dados_ml.head())
# Out:
#    total_upload  total_subscribers  total_video_views      country  \
# 0            72            70800.0       1.224873e+07  Afghanistan
# 1           384          4100000.0       1.277637e+09  Afghanistan
# 2            35          3680000.0       8.913827e+08  Afghanistan
# 3          3703          1930000.0       3.679132e+08  Afghanistan
# 4            49          1480000.0       7.852759e+08  Afghanistan
#
#     channel_type  day_created  month_created  year_created  channel_age  \
# 0         People           27              5          2016            8
# 1  Entertainment           10              9          2019            4
# 2         Comedy           11              7          2006           17
# 3  Entertainment            3              1          2017            7
# 4          Music           15              8          2016            7
#
#    rank_social_blade  rank_subscribers  rank_video_views rank_country  \
# 0           914134.0            2789.0          881538.0           83
# 1           109567.0             955.0           12079.0            1
# 2            67156.0            1000.0           18740.0            2
# 3           254881.0            1179.0           48725.0            3
# 4           349028.0            1226.0           21567.0            5
#
#    Minimum_Estimated_Monthly_Earnings  videos_views_last_30_days  \
# 0                                0.02                       81.0
# 1                             1200.00                  4937000.0
# 2                             2200.00                  8895000.0
# 3                              371.00                  1486000.0
# 4                              244.00                   975249.0
#
#    subscribers_for_last_30_days  Populacao_2022  PIB_Nominal_2022  \
# 0                        -100.0      41128771.0      1.427000e+10
# 1                       10000.0      41128771.0      1.427000e+10
# 2                       10000.0      41128771.0      1.427000e+10
# 3                       20000.0      41128771.0      1.427000e+10
# 4                           0.0      41128771.0      1.427000e+10
#
#    PIB_per_Capita_2022  Exp_de_Vida_2022  Taxa_de_Natalidade  \
# 0           352.603733            62.879               32.49
# 1           352.603733            62.879               32.49
# 2           352.603733            62.879               32.49
# 3           352.603733            62.879               32.49
# 4           352.603733            62.879               32.49
#
#    taxa_alfabetizacao_total_%  taxa_alfabetizacao_masculina_%  \
# 0                        38.2                            52.0
# 1                        38.2                            52.0
# 2                        38.2                            52.0
# 3                        38.2                            52.0
# 4                        38.2                            52.0
#
#    taxa_alfabetizacao_feminina_%  diferenca_alfabetizacao_masculino_feminino  \
# 0                           24.2                                        27.8
# 1                           24.2                                        27.8
# 2                           24.2                                        27.8
# 3                           24.2                                        27.8
# 4                           24.2                                        27.8
#
#    Taxa_Desemprego_2022_%  Taxa_de_Pobreza  Indice_de_Watts  \
# 0                    14.1            0.494           0.2876
# 1                    14.1            0.494           0.2876
# 2                    14.1            0.494           0.2876
# 3                    14.1            0.494           0.2876
# 4                    14.1            0.494           0.2876
#
#   Human_Development_Groups  IDH_2021  Indice_Corrupcao_Score  \
# 0                      Low     0.478                    20.0
# 1                      Low     0.478                    20.0
# 2                      Low     0.478                    20.0
# 3                      Low     0.478                    20.0
# 4                      Low     0.478                    20.0
#
#    Nivel_Urbanizacao_2023_%_da_Pop
# 0                           26.616
# 1                           26.616
# 2                           26.616
# 3                           26.616
# 4                           26.616

# %% [markdown]
# <br>
#
# ## Aplicando Label Encoding

# %%
# Exibindo Variáveis Categóricas (filtrando)
dados_ml.dtypes[dados_ml.dtypes == 'object']
# Out:
# country                     object
# channel_type                object
# rank_country                object
# Human_Development_Groups    object
# dtype: object

# %%
# Lista de variáveis categóricas (adicionar variáveis categóricas necessárias)
categorical_vars = ['country', 'channel_type', 'Human_Development_Groups']

# Aplicando Label Encoding
label_encoders = {}
for var in categorical_vars:
    le = LabelEncoder()
    dados_ml[var] = le.fit_transform(dados_ml[var])
    label_encoders[var] = le

    
# Converter a variável rank_country para o tipo numérico
dados_ml['rank_country'] = pd.to_numeric(dados_ml['rank_country'], errors='coerce')
    
# Verificando os tipos das variáveis
print('\nTipos das Variáveis Após Label Encoding\n')
print(dados_ml.dtypes)
# Out:
# Tipos das Variáveis Após Label Encoding
#
# total_upload                                    int64
# total_subscribers                             float64
# total_video_views                             float64
# country                                         int64
# channel_type                                    int64
# day_created                                     int64
# month_created                                   int64
# year_created                                    int64
# channel_age                                     int64
# rank_social_blade                             float64
# rank_subscribers                              float64
# rank_video_views                              float64
# rank_country                                  float64
# Minimum_Estimated_Monthly_Earnings            float64
# videos_views_last_30_days                     float64
# subscribers_for_last_30_days                  float64
# Populacao_2022                                float64
# PIB_Nominal_2022                              float64
# PIB_per_Capita_2022                           float64
# Exp_de_Vida_2022                              float64
# Taxa_de_Natalidade                            float64
# taxa_alfabetizacao_total_%                    float64
# taxa_alfabetizacao_masculina_%                float64
# taxa_alfabetizacao_feminina_%                 float64
# diferenca_alfabetizacao_masculino_feminino    float64
# Taxa_Desemprego_2022_%                        float64
# Taxa_de_Pobreza                               float64
# Indice_de_Watts                               float64
# Human_Development_Groups                        int64
# IDH_2021                                      float64
# Indice_Corrupcao_Score                        float64
# Nivel_Urbanizacao_2023_%_da_Pop               float64
# dtype: object

# %%
dados_ml.head()
# Out:
#    total_upload  total_subscribers  total_video_views  country  channel_type  \
# 0            72            70800.0       1.224873e+07        0            11
# 1           384          4100000.0       1.277637e+09        0             4
# 2            35          3680000.0       8.913827e+08        0             2
# 3          3703          1930000.0       3.679132e+08        0             4
# 4            49          1480000.0       7.852759e+08        0             8
#
#    day_created  month_created  year_created  channel_age  rank_social_blade  \
# 0           27              5          2016            8           914134.0
# 1           10              9          2019            4           109567.0
# 2           11              7          2006           17            67156.0
# 3            3              1          2017            7           254881.0
# 4           15              8          2016            7           349028.0
#
#    rank_subscribers  rank_video_views  rank_country  \
# 0            2789.0          881538.0          83.0
# 1             955.0           12079.0           1.0
# 2            1000.0           18740.0           2.0
# 3            1179.0           48725.0           3.0
# 4            1226.0           21567.0           5.0
#
#    Minimum_Estimated_Monthly_Earnings  videos_views_last_30_days  \
# 0                                0.02                       81.0
# 1                             1200.00                  4937000.0
# 2                             2200.00                  8895000.0
# 3                              371.00                  1486000.0
# 4                              244.00                   975249.0
#
#    subscribers_for_last_30_days  Populacao_2022  PIB_Nominal_2022  \
# 0                        -100.0      41128771.0      1.427000e+10
# 1                       10000.0      41128771.0      1.427000e+10
# 2                       10000.0      41128771.0      1.427000e+10
# 3                       20000.0      41128771.0      1.427000e+10
# 4                           0.0      41128771.0      1.427000e+10
#
#    PIB_per_Capita_2022  Exp_de_Vida_2022  Taxa_de_Natalidade  \
# 0           352.603733            62.879               32.49
# 1           352.603733            62.879               32.49
# 2           352.603733            62.879               32.49
# 3           352.603733            62.879               32.49
# 4           352.603733            62.879               32.49
#
#    taxa_alfabetizacao_total_%  taxa_alfabetizacao_masculina_%  \
# 0                        38.2                            52.0
# 1                        38.2                            52.0
# 2                        38.2                            52.0
# 3                        38.2                            52.0
# 4                        38.2                            52.0
#
#    taxa_alfabetizacao_feminina_%  diferenca_alfabetizacao_masculino_feminino  \
# 0                           24.2                                        27.8
# 1                           24.2                                        27.8
# 2                           24.2                                        27.8
# 3                           24.2                                        27.8
# 4                           24.2                                        27.8
#
#    Taxa_Desemprego_2022_%  Taxa_de_Pobreza  Indice_de_Watts  \
# 0                    14.1            0.494           0.2876
# 1                    14.1            0.494           0.2876
# 2                    14.1            0.494           0.2876
# 3                    14.1            0.494           0.2876
# 4                    14.1            0.494           0.2876
#
#    Human_Development_Groups  IDH_2021  Indice_Corrupcao_Score  \
# 0                         1     0.478                    20.0
# 1                         1     0.478                    20.0
# 2                         1     0.478                    20.0
# 3                         1     0.478                    20.0
# 4                         1     0.478                    20.0
#
#    Nivel_Urbanizacao_2023_%_da_Pop
# 0                           26.616
# 1                           26.616
# 2                           26.616
# 3                           26.616
# 4                           26.616

# %% [markdown]
# <br><br>
#
# ## Analisando Todas as Variáveis
#
# #### Resumo Estatístico

# %%
# Salvar o formato original
original_float_format = pd.options.display.float_format

# Ajustar a exibição do pandas para valores sem notação científica
pd.options.display.float_format = '{:.2f}'.format

# Verificando o resumo estatístico sem notação científica
print('\nSem Notação Científica')
display(dados_ml.describe())
print('\n----------------------------------------------------------------------------------------------\n\n')

# Restaurar o formato original
pd.options.display.float_format = original_float_format

# Verificando o resumo estatístico novamente para confirmar que voltou ao normal
#print('\nCom Notação Científica')
#display(dados.describe())
# Out:
# Sem Notação Científica
#        total_upload  total_subscribers  total_video_views  country  \
# count       1349.00            1349.00            1349.00  1349.00
# mean        4991.91         8989849.23      4849967502.24    49.97
# std        24767.08        17965998.03     12824683592.75    27.41
# min            0.00               0.00               0.00     0.00
# 25%          254.00           86900.00        16200823.00    23.00
# 50%          739.00         2610000.00       785785599.00    43.00
# 75%         1782.00        10800000.00      4393078691.00    82.00
# max       426935.00       289000000.00    258896707763.00    89.00
#
#        channel_type  day_created  month_created  year_created  channel_age  \
# count       1349.00      1349.00        1349.00       1349.00      1349.00
# mean           6.84        15.76           6.27       2015.55         7.97
# std            3.94         8.69           3.40          5.15         5.14
# min            0.00         1.00           1.00       2005.00         0.00
# 25%            4.00         8.00           3.00       2012.00         3.00
# 50%            6.00        16.00           6.00       2016.00         7.00
# 75%           11.00        23.00           9.00       2020.00        12.00
# max           16.00        31.00          12.00       2024.00        19.00
#
#        rank_social_blade  rank_subscribers  rank_video_views  rank_country  \
# count            1349.00           1349.00           1349.00       1348.00
# mean           166512.28          10340.33         356022.24        511.36
# std            305578.76         156619.39         982371.70       1011.93
# min                 1.00              1.00              1.00          1.00
# 25%              1539.00            336.00           1443.00         27.00
# 50%             10447.00            959.00           9436.00        144.00
# 75%            116359.00           1694.00          98068.00        601.50
# max           1107983.00        4493626.00        4514321.00       9791.00
#
#        Minimum_Estimated_Monthly_Earnings  videos_views_last_30_days  \
# count                             1349.00                    1349.00
# mean                             43145.72               165219613.84
# std                             124218.76               505329047.61
# min                                  0.00             -3350000000.00
# 25%                                892.00                 3232000.00
# 50%                              11100.00                43371000.00
# 75%                              43800.00               174660000.00
# max                            3300000.00             13187000000.00
#
#        subscribers_for_last_30_days  Populacao_2022  PIB_Nominal_2022  \
# count                       1349.00         1349.00           1349.00
# mean                      259555.00    363026951.91  6253066225110.26
# std                       926445.47    492791895.74  9307697805337.38
# min                      -100000.00        15040.00      336000000.00
# 25%                         8000.00     46234830.00   631133384439.94
# 50%                        90000.00    215313498.00  1920095779022.73
# 75%                       300000.00    333271411.00  3416645826052.87
# max                     27000000.00   1417173173.00 25439700000000.00
#
#        PIB_per_Capita_2022  Exp_de_Vida_2022  Taxa_de_Natalidade  \
# count              1349.00           1349.00             1349.00
# mean              31178.70             75.22               13.79
# std               30567.61              5.53                4.61
# min                 352.60             60.96                6.40
# 25%                5715.28             71.47               11.00
# 50%               13974.45             76.06               12.60
# 75%               55509.39             79.72               17.86
# max              187267.13             84.50               40.73
#
#        taxa_alfabetizacao_total_%  taxa_alfabetizacao_masculina_%  \
# count                     1349.00                         1349.00
# mean                        89.64                           91.59
# std                         10.48                            7.56
# min                         38.20                           52.00
# 25%                         88.00                           88.00
# 50%                         92.60                           92.20
# 75%                         98.80                           99.00
# max                         99.90                          100.00
#
#        taxa_alfabetizacao_feminina_%  \
# count                        1349.00
# mean                           87.55
# std                            13.95
# min                            24.20
# 25%                            88.00
# 50%                            92.90
# 75%                            98.70
# max                           100.00
#
#        diferenca_alfabetizacao_masculino_feminino  Taxa_Desemprego_2022_%  \
# count                                     1349.00                 1349.00
# mean                                         4.04                    5.83
# std                                          7.42                    3.60
# min                                         -9.10                    0.91
# 25%                                          0.00                    3.65
# 50%                                          0.00                    4.82
# 75%                                          4.20                    7.39
# max                                         27.80                   28.84
#
#        Taxa_de_Pobreza  Indice_de_Watts  Human_Development_Groups  IDH_2021  \
# count          1349.00          1349.00                   1349.00   1349.00
# mean              0.04             0.02                      2.02      0.81
# std               0.07             0.04                      1.24      0.12
# min               0.00             0.00                      0.00      0.48
# 25%               0.00             0.00                      1.00      0.72
# 50%               0.01             0.01                      3.00      0.82
# 75%               0.09             0.02                      3.00      0.92
# max               0.49             0.30                      3.00      0.96
#
#        Indice_Corrupcao_Score  Nivel_Urbanizacao_2023_%_da_Pop
# count                 1349.00                          1349.00
# mean                    52.11                            71.65
# std                     17.89                            19.72
# min                     17.00                            14.54
# 25%                     36.00                            62.82
# 50%                     42.00                            81.51
# 75%                     69.00                            84.40
# max                     90.00                           100.00
# ----------------------------------------------------------------------------------------------

# %% [markdown]
# #### Visualizando através de Gráficos Histograma

# %%
# Plot
dados_ml.hist(figsize = (15,15), bins = 10) 
plt.show()

print('\n\n------------------------------------------------------------------------------------------------\n')

# Visualização dos outliers
#plt.figure(figsize=(15, 10))
#sns.boxplot(data=dados_ml)
#plt.xticks(rotation=90)
#plt.title('Boxplot para Detecção de Outliers')
#plt.show()

# Visualização dos outliers, exceto para a coluna 'PIB_Nominal_2022'
plt.figure(figsize=(15, 10))
sns.boxplot(data=dados_ml[[col for col in dados_ml.columns if col != 'PIB_Nominal_2022']])
plt.xticks(rotation=90)
plt.title('Boxplot para Detecção de Outliers (exceto PIB_Nominal_2022)')
plt.show()
# Out:
# ------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Resumo da Análise
#
# <table border="2">
#   <tr>
#     <th style="text-align: center; font-size: 16px;">Nome Da Variável</th>
#     <th style="text-align: center; font-size: 16px;">Resumo_Análise</th>
#     <th style="text-align: center; font-size: 16px;">Tratamento Antes Divisão</th>
#     <th style="text-align: center; font-size: 16px;">Tratamento Depois Divisão</th>
#   </tr>
#   <tr>
#     <td>total_upload</td>
#     <td>Distribuição com valores altos e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>total_subscribers</td>
#     <td>Distribuição com valores altos e outliers significativos.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>total_video_views</td>
#     <td>Distribuição com alta variação e presença de outliers extremos.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>country</td>
#     <td>Variável categórica representando diferentes países.</td>
#     <td>Já foi aplicado Label Encoding</td>
#     <td>Não Necessita de Tratamento</td>
#   </tr>
#   <tr>
#     <td>channel_type</td>
#     <td>Variável categórica representando diferentes tipos de canais.</td>
#     <td>Já foi aplicado Label Encoding</td>
#     <td>Não Necessita de Tratamento</td>
#   </tr>
#   <tr>
#     <td>day_created</td>
#     <td>Distribuição uniforme dos dias de criação dos canais.</td>
#     <td>Não Necessita de Tratamento</td>
#     <td>Não Necessita de Tratamento</td>
#   </tr>
#   <tr>
#     <td>month_created</td>
#     <td>Distribuição uniforme dos meses de criação dos canais.</td>
#     <td>Não Necessita de Tratamento</td>
#     <td>Não Necessita de Tratamento</td>
#   </tr>
#   <tr>
#     <td>year_created</td>
#     <td>Distribuição dos anos de criação dos canais, com maior concentração nos últimos anos.</td>
#     <td>Não Necessita de Tratamento</td>
#     <td>Não Necessita de Tratamento</td>
#   </tr>
#   <tr>
#     <td>channel_age</td>
#     <td>Distribuição com valores variáveis e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>rank_social_blade</td>
#     <td>Distribuição com alta variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>rank_subscribers</td>
#     <td>Distribuição com alta variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>rank_video_views</td>
#     <td>Distribuição com alta variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>rank_country</td>
#     <td>Distribuição com valores variáveis e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>Minimum_Estimated_Monthly_Earnings</td>
#     <td>Distribuição com valores variados e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>videos_views_last_30_days</td>
#     <td>Distribuição com alta variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>subscribers_for_last_30_days</td>
#     <td>Distribuição com alta variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>Populacao_2022</td>
#     <td>Distribuição com alta variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>PIB_Nominal_2022</td>
#     <td>Distribuição com alta variação e presença de outliers extremos.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>PIB_per_Capita_2022</td>
#     <td>Distribuição com alta variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>Exp_de_Vida_2022</td>
#     <td>Distribuição com menor variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>Taxa_de_Natalidade</td>
#     <td>Distribuição com menor variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>taxa_alfabetizacao_total_%</td>
#     <td>Distribuição com menor variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>taxa_alfabetizacao_masculina_%</td>
#     <td>Distribuição com menor variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>taxa_alfabetizacao_feminina_%</td>
#     <td>Distribuição com menor variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>diferenca_alfabetizacao_masculino_feminino</td>
#     <td>Distribuição com menor variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>Taxa_Desemprego_2022_%</td>
#     <td>Distribuição com menor variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>Taxa_de_Pobreza</td>
#     <td>Distribuição com menor variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>Indice_de_Watts</td>
#     <td>Distribuição com menor variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>Human_Development_Groups</td>
#     <td>Variável categórica representando grupos de desenvolvimento humano.</td>
#     <td>Já foi aplicado Label Encoding</td>
#     <td>Não Necessita de Tratamento</td>
#   </tr>
#   <tr>
#     <td>IDH_2021</td>
#     <td>Distribuição com alta variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>Indice_Corrupcao_Score</td>
#     <td>Distribuição com alta variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
#   <tr>
#     <td>Nivel_Urbanizacao_2023_%_da_Pop</td>
#     <td>Distribuição com alta variação e presença de outliers.</td>
#     <td>Tratamento para Outliers</td>
#     <td>Normalização</td>
#   </tr>
# </table>

# %%
dados_ml.columns
# Out:
# Index(['total_upload', 'total_subscribers', 'total_video_views', 'country',
#        'channel_type', 'day_created', 'month_created', 'year_created',
#        'channel_age', 'rank_social_blade', 'rank_subscribers',
#        'rank_video_views', 'rank_country',
#        'Minimum_Estimated_Monthly_Earnings', 'videos_views_last_30_days',
#        'subscribers_for_last_30_days', 'Populacao_2022', 'PIB_Nominal_2022',
#        'PIB_per_Capita_2022', 'Exp_de_Vida_2022', 'Taxa_de_Natalidade',
#        'taxa_alfabetizacao_total_%', 'taxa_alfabetizacao_masculina_%',
#        'taxa_alfabetizacao_feminina_%',
#        'diferenca_alfabetizacao_masculino_feminino', 'Taxa_Desemprego_2022_%',
#        'Taxa_de_Pobreza', 'Indice_de_Watts', 'Human_Development_Groups',
#        'IDH_2021', 'Indice_Corrupcao_Score',
#        'Nivel_Urbanizacao_2023_%_da_Pop'],
#       dtype='object')

# %% [markdown]
# <br>
#
# # Limpeza nos Dados
#
# <br>
#
# ### Tratando Valores Outliers

# %% [markdown]
# #### total_upload

# %%
# Describe
print(dados_ml['total_upload'].describe())

print('\n-----------------------------------------------------------------------------------------------------\n')

# Visualização dos outliers
plt.figure(figsize=(15, 10))
sns.boxplot(data=dados_ml['total_upload'])
plt.xticks(rotation=90)
plt.title('Boxplot para Detecção de Outliers')
plt.show()
# Out:
# count      1349.000000
# mean       4991.906597
# std       24767.080583
# min           0.000000
# 25%         254.000000
# 50%         739.000000
# 75%        1782.000000
# max      426935.000000
# Name: total_upload, dtype: float64
#
# -----------------------------------------------------------------------------------------------------

# %%
APLICAR WINSOZIRED NESTA VARIÁVEL E VERIFICAR OUTRAS


from scipy.stats.mstats import winsorize

# Aplicar Winsorização para limitar os outliers
dados_ml['total_upload_winsorized'] = winsorize(dados_ml['total_upload'], limits=[0.01, 0.01])

# Describe da nova variável transformada
print(dados_ml['total_upload_winsorized'].describe())

print('\n-----------------------------------------------------------------------------------------------------\n')

# Visualização dos outliers da nova variável transformada
plt.figure(figsize=(15, 10))
sns.boxplot(data=dados_ml['total_upload_winsorized'])
plt.xticks(rotation=90)
plt.title('Boxplot para Detecção de Outliers (Winsorização)')
plt.show()
# Out:
# count      1349.000000
# mean       4240.568569
# std       16707.074101
# min           1.000000
# 25%         254.000000
# 50%         739.000000
# 75%        1782.000000
# max      135247.000000
# Name: total_upload_winsorized, dtype: float64
#
# -----------------------------------------------------------------------------------------------------

# %% [markdown]
# - Verificar pela quantidade de uploads e data do canal quantos vídeos postou por mês e ano
# - Adicionar continente ou região a partir dos países
# - Verifificar qantidade de inscritos no youtube por país

# %% [markdown]
# # Calcular a média de vídeos postados por ano
# dados_ml['avg_uploads_per_year'] = dados_ml['total_upload'] / dados_ml['channel_age']
#
# # Calcular a média de vídeos postados por mês
# # Assumindo 12 meses por ano
# dados_ml['avg_uploads_per_month'] = dados_ml['total_upload'] / (dados_ml['channel_age'] * 12 + (12 - dados_ml['month_created']))
#
# # Calcular a média de vídeos postados por dia
# # Assumindo 365 dias por ano
# dados_ml['avg_uploads_per_day'] = dados_ml['total_upload'] / (dados_ml['channel_age'] * 365 + (365 - (dados_ml['month_created'] - 1) * 30 - dados_ml['day_created']))
#
# # Verificar as primeiras linhas para confirmação
# display(dados_ml[['total_upload', 'channel_age', 'avg_uploads_per_year', 'avg_uploads_per_month', 'avg_uploads_per_day']].head())

# %%
# Salvando o DataFrame atualizado
# dados.to_csv('dados/datasets_modificados/dados_completos_atualizado.csv', index=False)

# %%
# Ajustar as configurações de exibição do Pandas para visualizar todos os valores únicos
pd.set_option('display.max_rows', None)

# Filtrar as linhas onde o país é 'N/A'
#display(dados_da)

# Resetar as configurações de exibição do Pandas
pd.reset_option('display.max_rows')

# %% [markdown]
# # Dados dos canais Tech
# novos_canais = {
#     'channel_name': [
#         'Alice Brandão', 'The Weather Channel: New York City', 'Káthia Gregório', 'brasil', 'Adney Lima', 'France'
#     ],
#     'total_upload': [
#         97, 151, 472, 1, 14, 1
#     ],
#     'total_subscribers': [
#         234, 687, 320, 282, 323, 16700
#     ],
#     'total_video_views': [
#         20679, 90537, 149789, 2042, 22970, 1266
#     ],
#     'country': [
#         'BR', 'N/A', 'N/A', 'BR', 'N/A', 'US'
#     ],
#     'channel_type': [
#         'Music', 'News', 'Sports', 'Travel', 'N/A', 'N/A'
#     ],
#     'user_created': [
#         'Aug 7th, 2016', 'Sep 16th, 2013', 'Dec 20th, 2010', 'Nov 30th, 2005', 'Sep 13th, 2010', 'May 28th, 2022'
#     ],
#     'rank_social_blade': [
#         None, 914195, 914124, 914192, None, 914210
#     ],
#     'rank_subscribers': [
#         None, 18338, 18704, 18743, None, 7757
#     ],
#     'rank_video_views': [
#         None, 4423795, 4364541, 4512281, None, 4513055
#     ],
#     'rank_country': [
#         None, None, None, 6125, None, 3773
#     ],
#     'rank_channel_type': [
#         None, 4514, 4761, 3572, None, None
#     ],
#     'estimated_monthly_earnings': [
#         '0 - 0', '0.01 - 0.12', '0.02 - 0.36', '0.01 - 0.10', '6 - 92', '0.00 - 0.02'
#     ],
#     'estimated_yearly_earnings': [
#         '0 - 0', '0.09 - 1', '0.27 - 4', '0.08 - 1', '69 - 1.1K', '0.02 - 0.29'
#     ],
#     'videos_views_last_30_days': [
#         20605, 29, 89, 25, 22970, 6
#     ],
#     'subscribers_for_last_30_days': [
#         23, 2, 0, 7, 1, -100
#     ]
# }
#
#
# for key, value in novos_canais.items():
#     print(f"Tamanho da variável '{key}': {len(value)}")
#
#
# # Convertendo os novos dados ao DataFrame
# new_df = pd.DataFrame(novos_canais)
#
# # Aplicando a conversão de valores
# new_df["country"] = new_df["country"].apply(convert_country)
#
# # Concatenando com o DataFrame existente
# df = pd.concat([df, new_df], ignore_index=True)
#
# # Mostrando o DataFrame resultante
# display(df)

# %% [markdown]
# <table border="2" style="font-size: 14px; border-spacing: 10px;">
#   <caption style="font-size: 32px; margin: 30px; text-align: center">Pipeline para Modelos de Machine Learning (ML)</caption>
#   <tr>
#     <th style="text-align: center; font-size: 20px;">Passo</th>
#     <th style="text-align: center; font-size: 20px;">Descrição</th>
#     <th style="text-align: center; font-size: 20px;">Comentário</th>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Definir Objetivo e Pergunta de Negócio</td>
#     <td>Determinar o objetivo do projeto e as principais perguntas de negócio a serem respondidas.</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Importar Pacotes</td>
#     <td>Importar as bibliotecas e pacotes necessários para o projeto.</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Carregar dados</td>
#     <td>Esta é a primeira etapa essencial para qualquer projeto de Data Science.</td>
#   </tr>
#   <tr>
#     <td>4</td>
#     <td>Analisar Dados de forma Geral</td>
#     <td>Análise exploratória inicial para entender a estrutura e o conteúdo dos dados.</td>
#   </tr>
#   <tr>
#     <td>5</td>
#     <td>Remoção de Variáveis Completamente Irrelevantes</td>
#     <td>Remover variáveis que não contribuem para a análise ou que são completamente irrelevantes.</td>
#   </tr>
#   <tr>
#     <td>6</td>
#     <td>Renomear variáveis (se necessário)</td>
#     <td>Renomear as variáveis para melhor visualização e entendimento dos dados.</td>
#   </tr>
#   <tr>
#     <td>7</td>
#     <td>Analisar Dados de Variáveis Categóricas</td>
#     <td>É importante entender a distribuição e as características das variáveis categóricas.</td>
#   </tr>
#   <tr>
#     <td>8</td>
#     <td>Aplicar se necessário algum tratamento nas variáveis categóricas antes do Label Encode</td>
#     <td>Tratamentos como combinação de categorias raras ou correção de inconsistências devem ser feitos antes da codificação.</td>
#   </tr>
#   <tr>
#     <td>9</td>
#     <td>Aplicar Label Encode nas variáveis categóricas</td>
#     <td>Convertendo variáveis categóricas em numéricas.</td>
#   </tr>
#   <tr>
#     <td>10</td>
#     <td>Analisar Todas as Variáveis com describe e gráficos</td>
#     <td>Análise estatística e visual de todas as variáveis para identificar padrões e anomalias.</td>
#   </tr>
#   <tr>
#     <td>11</td>
#     <td>Aplicar tratamento de Valores Ausentes</td>
#     <td>Tratar valores ausentes antes da modelagem para evitar problemas.</td>
#   </tr>
#   <tr>
#     <td>12</td>
#     <td>Aplicar Tratamento para Linhas Duplicadas</td>
#     <td>Remover ou lidar com linhas duplicadas para garantir a qualidade dos dados.</td>
#   </tr>
#   <tr>
#     <td>13</td>
#     <td>Aplicar Tratamento para Valores Outliers</td>
#     <td>Identificar e tratar outliers que possam afetar a performance do modelo.</td>
#   </tr>
#   <tr>
#     <td>14</td>
#     <td>Features Engineering (se necessário)</td>
#     <td>Criar novas variáveis ou transformar variáveis existentes para melhorar a capacidade preditiva do modelo.</td>
#   </tr>
#   <tr>
#     <td>15</td>
#     <td>Aplicar Clusterização (se necessário)</td>
#     <td>Identificar padrões ou segmentos nos dados para insights adicionais.</td>
#   </tr>
#   <tr>
#     <td>16</td>
#     <td>Análise de Correlação</td>
#     <td>Identificar relações entre as variáveis que podem informar a seleção de variáveis.</td>
#   </tr>
#   <tr>
#     <td>17</td>
#     <td>Seleção de Variáveis</td>
#     <td>Selecionar as variáveis mais relevantes para a modelagem.</td>
#   </tr>
#     <tr>
#     <td>18</td>
#     <td>Remoção de Variáveis Após Análise de Correlação e Seleção de Variáveis (se necessário)</td>
#     <td>Remover variáveis que não são relevantes com base nas análises de correlação e Seleção de Variáveis.</td>
#   </tr>
#   <tr>
#     <td>19</td>
#     <td>Divisão dos Dados em Treino e Teste</td>
#     <td>Separar os dados para validar o desempenho do modelo.</td>
#   </tr>
#   <tr>
#     <td>20</td>
#     <td>Aplicar Normalização ou Padronização (Depende dos dados)</td>
#     <td>Aplicar transformações de escala. Normalizar ou padronizar os dados após a divisão em treino e teste para evitar vazamento de dados.</td>
#   </tr>
#   <tr>
#     <td>21</td>
#     <td>Criar Modelo Benchmark para ver como está o desempenho do modelo inicial</td>
#     <td>Criar um modelo inicial simples para ter uma linha de base de desempenho.</td>
#   </tr>
#   <tr>
#     <td>22</td>
#     <td>Se o modelo Benchmark estiver muito ruim, estudar formas de tentar melhorar o conjunto de dados</td>
#     <td>Melhorar os dados, se necessário, para tentar aumentar o desempenho do modelo.</td>
#   </tr>
#   <tr>
#     <td>23</td>
#     <td>Treinar outros algoritmos</td>
#     <td>Testar múltiplos algoritmos para encontrar o mais adequado.</td>
#   </tr>
#   <tr>
#     <td>24</td>
#     <td>Verificar desempenho dos algoritmos</td>
#     <td>Comparar os desempenhos para selecionar o melhor modelo.</td>
#   </tr>
#   <tr>
#     <td>25</td>
#     <td>Escolher e salvar o melhor modelo</td>
#     <td>Selecionar o modelo com melhor desempenho e salvá-lo para uso futuro, incluindo no pipeline as informações necessárias para desnormalizar ou despadronizar os dados, bem como os labels e outras configurações.</td>
#   </tr>
#   <tr>
#     <td>26</td>
#     <td>Testar o modelo com dados novos</td>
#     <td>Validar o modelo com novos dados para verificar sua capacidade de generalização.</td>
#   </tr>
#   <tr>
#     <td>27</td>
#     <td>Criar uma Interface Gráfica do Modelo</td>
#     <td>Criar uma interface gráfica pode ser útil, mas não é um passo essencial em todos os projetos de Data Science.</td>
#   </tr>
# </table>
